# %%
Q1.who developed python programming languag?
ans=> Guido van Rossum in 1970.


Q2.which type of programming does python support?
ans=>Python support Object-oriented programming ,structured programming .
     it's a multi-paradigm programming language.
    

Q3.is python case sensitive when dealing with identifier?
ans=>yes,python is case sensitive language because they not same treated upper case & 
     lower case    eg.a!=A
    

Q4.what is the correct extension of the python file?
ans=>.py  is the extension of python file


Q5.is python code compiled or interpreted?
ans=>interpreted because they executed programe line by line.


Q6.name a few blocks of code used to define in python language?
ans=>Indentation is used to define a block of code in python.  
      WITH INDENTATION                       WITHOUT INDENTATION 
     if name=="sudh":                        if name=="sudh":
         print(name)                        print(name)    
        

Q7.state  a character used to give single-line comments in python language
ans=> # is used.


Q8.mention function which can help us to find version of python that we are currently working on?
ans=>python --version


Q9.python supports the creation of anomymous function at runtime,using a construct called?
ans=>lambda

Q10.what does pip stand for python?
ans=>pip stand for preferred installer program


Q11.mention a few built-in function in python?
ans=>there are many built in function in python like->list(),tuple(),type(),len(),pow()..etc


Q12.what is the maximum possible length of an identifier in python?
ans=>79


Q13.how is memory managed in python?
ans=>Memory management in Python involves a private heap containing all Python objects and data structures. 
      The management of this private heap is ensured internally by the Python memory manager


Q15.how to install python on windows and set path variables?
ans=>step1. Right-clicking This PC and going to Properties
     step1. Clicking on the Advanced system settings in the menu on the left
     step1. Clicking on the Environment Variables button o​n the bottom right.
  In the System variables section, selecting the Path variable and clicking on Edit.
  The next screen will show all the directories that are currently a part of the PATH variable.
     step4. Clicking on New and entering Python’s install directory
        

Q16.is indentation required in python?
ans=>yes, its very important to get space in if code because they show error.
